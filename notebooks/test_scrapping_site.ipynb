# %%
from bs4 import BeautifulSoup
import re
import time
import requests
import random
import string

import pandas as pd

# %%
def clean_text(text: str) -> str:
    txt = text.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
    txt = txt.replace('  ', ' ')
    return txt.strip()

def extract_by_regex(text: str, regex: str) -> str:
    pattern = re.compile(regex)
    match = pattern.search(text)
    if match:
        # Check if there are any groups and return the first group if it exists
        if match.groups():
            return match.group(1) + " " + match.group(2) if len(match.groups()) > 1 else match.group(1)
        else:
            return match.group(0)  # Return the entire match if no groups are defined
    return ""

def filter_by_regex(text, pattern):
    """Extract data using a regular expression."""
    match = re.sub(pattern, '', text)
    return match if match else None

# %%
class TripAdvisorScraper:
    """
    Base class for TripAdvisor scraping.
    All other classes inherit from this.
    """
    def __init__(self):
        self.url_base = "https://www.tripadvisor.fr"
        self.soup = None
        self.url = None
        self.full_url = None

    def fetch_page(self, url):
        """Fetch a page and set the soup."""
        self.url = url
        self.full_url = self.url_base + url
        random_request_id = "".join(
            random.choice(string.ascii_lowercase + string.digits) for _ in range(180)
        )

        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3",
            "accept-language": "en-US,en;q=0.9,fr;q=0.8",
            "X-Requested-By": random_request_id,
            "Referer": "https://www.tripadvisor.fr/Hotels",
            "Origin": "https://www.tripadvisor.fr",
            "accept-encoding": "gzip, deflate, br",
            "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
            "encoding": "utf-8",
        }

        response = requests.get(self.full_url, headers=headers)
        response.raise_for_status()
        self.soup = BeautifulSoup(response.content, "html.parser")

    def print_soup(self):
        """Print the soup for debugging purposes."""
        if self.soup:
            print(self.soup.prettify())
        else:
            print("Soup is not initialized. Fetch the page first.")

    def get_next_url(self):
        """Get the next page's URL."""
        next_button = self.soup.find(
            "a", class_="BrOJk u j z _F wSSLS tIqAi Vonfv",
            attrs={"aria-label": "Suivant"}
        )
        return next_button["href"] if next_button else None

# %%
class TripAdvisorSpecificRestaurantScraper(TripAdvisorScraper):
    """Scraper for reviews of a specific restaurant."""
    def __init__(self):
        super().__init__()
        self.restaurant_data = []

    def get_review_cards(self):
        """Extract review cards."""
        if self.soup:
            return self.soup.find_all("div", class_="_c")
        print("Soup not initialized. Fetch the page first.")
        return []

    def parse_review(self, review_card):
        """Parse data from a single review card."""
        review_text_class = "biGQs _P pZUbB KxBGd"
        contributions_class = "b"
        date_class = "biGQs _P pZUbB ncFvv osNWb"
        user_name_class = "BMQDV _F Gv wSSLS SwZTJ FGwzt ukgoS"
        rating_class = "UctUV d H0"

        review_text = review_card.find("div", class_=review_text_class).get_text(strip=True) if review_card.find("div", class_=review_text_class) else None
        contributions = review_card.find("span", class_=contributions_class).get_text(strip=True) if review_card.find("span", class_=contributions_class) else None
        date = review_card.find("div", class_=date_class).get_text(strip=True) if review_card.find("div", class_=date_class) else None
        user_name = review_card.find("a", class_=user_name_class).get_text(strip=True) if review_card.find("a", class_=user_name_class) else None
        rating = review_card.find("svg", class_=rating_class).title.text if review_card.find("svg", class_=rating_class) else None

        date = filter_by_regex(date, r"Rédigé le") if date else None
        rating = extract_by_regex(rating, r"(\d\,\d)") if rating else None
        
        return {
            "review_text": clean_text(review_text) if review_text else None,
            "contributions": contributions,
            "date": date,
            "user_name": user_name,
            "rating": rating,
        }

    def get_all_reviews(self):
        """Get all reviews from the restaurant."""
        reviews = []
        while self.url:
            time.sleep(random.uniform(1, 3))
            review_cards = self.get_review_cards()
            for card in review_cards:
                reviews.append(self.parse_review(card))
            self.url = self.get_next_url()
            if self.url:
                self.fetch_page(self.url)
        return reviews

# %%
url = '/Restaurant_Review-g187265-d23110895-Reviews-Frazarin-Lyon_Rhone_Auvergne_Rhone_Alpes.html'
restaurants_scrapper = TripAdvisorSpecificRestaurantScraper()
restaurants_scrapper.fetch_page(url)

# %%
cards = restaurants_scrapper.get_review_cards()
for card in cards:
    print(restaurants_scrapper.parse_review(card))
# Out:
# {'review_text': "Ambiance soignée, patrons amicaux et donnant toutes les explications bienvenues sur l'histoire de leur restaurant et sur les plats. De beaux plats, 2 à 3 choix par type. Très bien cuisiné, assaisonné et portions équilibrées. Belle carte des vins, très fournies. Bravo à vous, nous reviendrons", 'contributions': '8', 'date': '15 décembre 2024', 'user_name': 'Fred S', 'rating': '5,0'}
# {'review_text': 'Vous voulez bien manger, alors allez dans ce restaurant. Tout est parfait. L\'accueil, la sympathie du personnel, excellent. Vous pouvez même vous rendre en cuisine pour féliciter le cuisinier, il est très content d\'entendre votre satisfaction. Je le recommande vivement. En sortant du restaurant, mes amis m\'ont dit " il faut que l\'on revienne ici, trop bon "', 'contributions': '1', 'date': '27 novembre 2024', 'user_name': 'Guide38409630404', 'rating': '5,0'}
# {'review_text': 'Tout simplement parfait de l’entrée au dessert en passant par les vins et le service.  Assurément un des meilleurs restaurant de ma vie ! Merci Frazarin.', 'contributions': '4', 'date': '20 novembre 2024', 'user_name': 'Chartin M', 'rating': '5,0'}
# {'review_text': 'Belle soirée passée au Frazarin. Certainement encore plus recommandable pour les amateurs de vin(s). Personnel également très avenant.', 'contributions': '38', 'date': '18 novembre 2024', 'user_name': 'Axelfoley009', 'rating': '5,0'}
# {'review_text': "Très bon restaurant ! j'ai adoré le service et l'offre de restauration, le lieu est convivial ! je recommande à tous les amateur d'Italien", 'contributions': '1', 'date': '13 novembre 2024', 'user_name': 'Karine P', 'rating': '5,0'}
# {'review_text': "Restaurant situé rue de Condé, vous qui êtes de passage ou habitant de Lyon, vous ne pouvez pas passer à côté de cette pépite... Très belle déco et que dire de ce qui se passe dans l'assiette! Cuisine raffinée qui exaltera vos papilles et qui vous fera voyager jusqu'en Italie... Alors à vos fourchettes et bon appétit....", 'contributions': '8', 'date': '13 novembre 2024', 'user_name': 'Jérôme L', 'rating': '5,0'}
# {'review_text': 'Mon dîner plutôt italien avec en entrée (photo hélas floue) : gnudi (sorte de gnocchis) toscani, ricotta e spinacci, bouillon e lardo colonnata. C\'est sous forme de sphère - ricotta e spinacci), en fait enroulée dans de la colonnata, très très fine tranche de lard blanc frit, ressemblant à un Ha Kao mais plus translucide. Aussi surprenant à voir qu\'à déguster ; en plat : tagliatelle pomodoro, salsiccia, finicchio e menta. Le régal continue... en dolce (dessert ) : gros chou crème pralinée, mascarpone avec caramel beurre salé et noisettes caramélisées. Un "must" ! Avec, pour accompagner, un ballon de succulentissime Nero d\'Avola. Une adresse où se rendre sans hésiter à Lyon.', 'contributions': '173', 'date': '22 octobre 2024', 'user_name': 'aquario13', 'rating': '5,0'}
# {'review_text': 'Déjà à l’entrée, on y est accueilli avec gentillesse. Le service est personnalisé puisqu’on prend le temps d’expliquer le menu. Il ne faut pas s’attendre à un menu très diversifié, mais ce qui est proposé est bien cuisiné et recherché. Bref, c’est vrai que c’est bon.', 'contributions': '270', 'date': '17 octobre 2024', 'user_name': 'M@lt', 'rating': '5,0'}
# {'review_text': 'Accueil très sympathique, plats originaux et très expressifs. Très bons conseils sur les vins. Une très bonne adresse.', 'contributions': '1', 'date': '11 octobre 2024', 'user_name': 'Muriel J', 'rating': '5,0'}
# {'review_text': 'Dès qu’on pousse la porte, on est chaleureusement accueilli par d’immenses sourires. Le personnel est très sympathique et convivial ( un immense merci à Quentin qui connaît même la petite commune de Linkebeek 😂). La suite n’est pas en reste : une belle vaisselle, une présentation très soignée et des plats délicieux et de qualité. Bref, on vous le recommande les yeux fermés. Encore merci à vous.', 'contributions': '182', 'date': '26 septembre 2024', 'user_name': 'Isabelle C', 'rating': '5,0'}
# {'review_text': "TOUT EST FAIT MAISON ET CA SE VOIT!!!! le déjeuner permet de choisir sa formule (plat ou entée plat ou plat dessert ou plat fromage ou entrée plat dessert/fromage) maximum 30 euros Les saveurs sont exquises, vraiment. Et l'accueil est extrêmement sympathique. Je reviendrai. JE RECOMMANDE!", 'contributions': '339', 'date': '22 septembre 2024', 'user_name': 'MissEmmaR', 'rating': '5,0'}
# {'review_text': "Restaurant génial : le personnel est adorable et aux petits soins, les plats sont excellents, les prix corrects, le lieu est joli et pas trop bruyant. On voit des passionnés a l'œuvre et ça donne un repas super :)", 'contributions': '2', 'date': '20 septembre 2024', 'user_name': 'Alizée S', 'rating': '5,0'}
# {'review_text': 'Très belle découverte, nous avons passé une excellente soirée . La cuisine est délicieuse, de bons produits parfaitement mis en valeur ! Nous avons été judicieusement conseillés pour le choix des vins , le tout dans une ambiance chaleureuse et un cadre très agréable. Nous reviendrons avec plaisir !', 'contributions': '10', 'date': '14 septembre 2024', 'user_name': 'claudine d', 'rating': '5,0'}
# {'review_text': 'Super moment ! Cuisine exceptionnelle et service incontournable… je recommande grandement ! Voyage entre l’Italie la france et une bande de pote', 'contributions': '1', 'date': '12 septembre 2024', 'user_name': 'Oscar L', 'rating': '5,0'}
# {'review_text': 'Excellent restaurant avec une influence italienne. Le serveur Max nous a très bien conseillés sur le vin. Vous pouvez y aller les yeux fermés et vous ne serez pas déçu 🤌', 'contributions': '23', 'date': '12 juin 2024', 'user_name': 'Mical A', 'rating': '5,0'}
